# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandumeghanajogi/Chandumeghana_FMML_LABS_PROJECTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 08:14:55--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   116MB/s    in 0.6s
#
# 2024-04-03 08:14:56 (116 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 18233  cs/0609142v1  The aim of this paper is to provide a sound fr...    cs
# 17111  1708.06022v1  Question answering (QA) systems are sensitive ...    cs
# 6822   1706.04983v2  The early layers of a deep neural net have the...  stat
# 22637  1703.04335v1  We propose a novel Bayesian Optimization appro...  stat
# 1041   1608.03639v1  A major contributing factor to the recent adva...  stat
# ...             ...                                                ...   ...
# 30197  1711.08879v1  Objects for detection usually have distinct ch...    cs
# 12310  1711.06705v1  We revisit the classification problem and focu...  stat
# 15509  1508.00305v1  Two important aspects of semantic parsing for ...    cs
# 23842   1109.3637v1  Global voting schemes based on the Hough trans...    cs
# 30658  1712.09531v1  Although many methods perform well in single c...    cs
#
#                                                    title  year  \
# 18233                          Modular self-organization  2006
# 17111      Learning to Paraphrase for Question Answering  2017
# 6822   FreezeOut: Accelerate Training by Progressivel...  2017
# 22637  Practical Bayesian Optimization for Variable C...  2017
# 1041   Faster Training of Very Deep Networks Via p-No...  2016
# ...                                                  ...   ...
# 30197    Feature Selective Networks for Object Detection  2017
# 12310         Principal Boundary on Riemannian Manifolds  2017
# 15509  Compositional Semantic Parsing on Semi-Structu...  2015
# 23842  Connectivity-Enforcing Hough Transform for the...  2011
# 30658  Multi-Target, Multi-Camera Tracking by Hierarc...  2017
#
#                                                 keywords
# 18233  [framework, addressing, difficult, automatic, ...
# 17111  [answering, sensitive, different, expresses, i...
# 6822   [parameters, computation, excluding, experimen...
# 22637  [optimization, functions, environmental, deter...
# 1041   [contributing, structural, information, gradie...
# ...                                                  ...
# 30197  [detection, characteristics, different, differ...
# 12310  [classification, nonlinear, classification, ma...
# 15509  [important, answering, knowledge, compositiona...
# 23842  [transform, connectivity, cluttered, oppositio...
# 30658  [challenging, attention, annotated, benchmark,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 18233    [framework, addressing, difficult, automatic, ...
# 17111    [answering, sensitive, different, expresses, i...
# 6822     [parameters, computation, excluding, experimen...
# 22637    [optimization, functions, environmental, deter...
# 1041     [contributing, structural, information, gradie...
#                                ...
# 22797    [treatment, quantitative, decisions, education...
# 11159    [framework, estimation, transform, regularizat...
# 33227    [simulating, astrocyte, cerebrovascular, sugge...
# 10604    [confounders, reconstruct, regression, inferen...
# 1886     [structured, prediction, architectures, functi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8610 words.
# Out of those 4547 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7efbc560-197a-4f5d-a39f-4e2a59e69a0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7efbc560-197a-4f5d-a39f-4e2a59e69a0a")) {                    Plotly.newPlot(                        "7efbc560-197a-4f5d-a39f-4e2a59e69a0a",                        [{"x":["construction","architecture","uncorrelated","apparently","automatic","addressing","processes","fundamental","organizing","framework","difficult","autonomous","organization","clustering","competitive","expresses","experimental","consistently","information","sensitive","expressions","different","linguistic","knowledge","paraphrases","supervision","achieving","selection","answering","capturing","performance","paraphrase","progressively","empirically","parameters","excluding","available","demonstrate","computation","improvement","accelerate","experiments","effective","benchmark","evaluations","approaches","practical","acquisition","implemented","synthetic","objectives","overheads","evaluation","environmental","optimization","functions","determines","propagate","structure","controllable","recurrent","structural","feedforward","translation","gradients","including","contributing","analysing","significantly","consequence","simulator","considerable","realistic","algorithms","alternative","efficiency","components","reinforcement","inference","undesirable","baselines","attracted","heuristic","modulated","influence","perception","extracting","nonstationary","circumstances","frequency","dimension","predictability","subcomponent","switching","transition","similarity","embedding","component","successfully","coefficients","denoising","formulated","principles","variation","promising","smoothing","variational","inpainting","regularization","investigates","dimensional","functional","minimization","supervised","extensive","processing","demonstrated","classification","approximate","compressed","combination","exhibiting","introduced","regression","therefore","belonging","comparable","previously","introduce","correlated","measurement","formulation","literature","regularizer","conceptually","integrated","integrating","guidelines","incorporating","evolution","ontologies","represented","consistency","languages","techniques","management","specified","lifecycle","probabilistic","illustrate","empirical","scalability","overfitting","representation","parametric","advantages","attending","sequential","distances","construct","sequences","distributed","specifications","objective","constraint","programming","inequality","important","graphical","scientific","implementation","convergence","generated","constraints","quadratic","evaluated","interface","distribute","unsupervised","outperforms","complexity","handwritten","boltzmann","superpixel","recognition","constructed","categorize","computational","efficient","algorithm","restricted","effectively","superpixels","iterative","technique","categories","laplacian","dependency","providing","generalizes"],"y":[76,267,2,8,185,31,83,87,13,539,158,75,19,169,115,3,379,36,688,52,33,741,70,337,5,51,75,154,57,46,881,7,21,67,253,2,297,562,149,154,28,587,278,195,52,414,140,47,107,139,34,4,247,21,354,212,16,10,350,4,121,78,19,111,38,261,8,17,245,25,14,34,64,587,101,167,108,100,226,7,77,24,53,1,61,41,68,4,9,58,64,3,1,10,31,155,104,102,87,38,43,35,34,67,116,20,56,9,86,31,172,49,71,182,174,297,95,513,105,29,113,6,147,138,143,14,89,103,338,32,37,83,101,17,8,52,49,15,56,59,18,81,69,100,381,54,34,2,163,70,156,30,25,373,41,78,3,69,34,84,103,100,11,170,91,117,7,376,72,31,129,112,177,136,33,144,32,9,156,268,208,33,10,10,360,55,9,302,417,858,40,132,14,75,231,70,14,55,91,30],"type":"bar"},{"x":["construction","architecture","uncorrelated","apparently","automatic","addressing","pro ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4547,), (4547, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Out</span> <span style=''>of</span> <span style=''>focus</span> <span style=''>Blur</span> <span style=''>Image</span> <span style=''>De</span> <span style=''>blurring</span> <br/><br/><span style=''>Image</span> <span style=''>de</span> <span style=''>blurring</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>in</span> <span style=''>many</span> <span style=''>cases</span> <span style=''>of</span> <span style=''>imaging</span> <span style=''>a</span> <span style=''>real</span> <span style=''>scene</span> <span style=''>or</span> <span style=''>object</span> <span style=''>by</span> <span style=''>a</span> <span style=''>camera</span> <span style=''>This</span> <span style=''>project</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>de</span> <span style=''>blurring</span> <span style=''>an</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>distorted</span> <span style=''>by</span> <span style=''>an</span> <span style=''>out</span> <span style=''>of</span> <span style=''>focus</span> <span style=''>blur</span> <span style=''>through</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simulation</span> <span style=''>study</span> <span style=''>A</span> <span style=''>pseudo</span> <span style=''>inverse</span> <span style=''>filter</span> <span style=''>is</span> <span style=''>first</span> <span style=''>explored</span> <span style=''>but</span> <span style=''>it</span> <span style=''>fails</span> <span style=''>because</span> <span style=''>of</span> <span style=''>severe</span> <span style=''>noise</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>amplification</span> <span style=''>Then</span> <span style=''>Tikhonov</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>employed</span> <span style=''>which</span> <span style=''>produce</span> <span style=''>greatly</span> <span style=''>improved</span> <span style=''>results</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>pseudo</span> <span style=''>inverse</span> <span style=''>filter</span> <span style=''>In</span> <span style=''>Tikhonov</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>critical</span> <span style=''>rule</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtaining</span> <span style=''>a</span> <span style=''>high</span> <span style=''>quality</span> <span style=''>image</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>regularized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>possess</span> <span style=''>a</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.33134328358208953);'>convergence</span> <span style=''>property</span> <span style=''>The</span> <span style=''>best</span> <span style=''>result</span> <span style=''>with</span> <span style=''>the</span> <span style=''>relative</span> <span style='background-color:rgba(0, 255, 0, 0.6521739130434783);'>restoration</span> <span style=''>error</span> <span style=''>of</span> <span style=''>849</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prescribed</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reduction</span> <span style=''>Survey</span> <span style=''>Insights</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generalizations</span> <br/><br/><span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cornerstone</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretations</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attractive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>These</span> <span style=''>methods</span> <span style=''>capture</span> <span style=''>many</span> <span style=''>data</span> <span style=''>features</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>between</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>input</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>and</span> <span style=''>margin</span> <span style=''>between</span> <span style=''>data</span> <span style=''>classes</span> <span style=''>Methods</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>with</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>names</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivations</span> <span style=''>in</span> <span style=''>many</span> <span style=''>fields</span> <span style=''>and</span> <span style=''>perhaps</span> <span style=''>as</span> <span style=''>a</span> <span style=''>result</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connections</span> <span style=''>between</span> <span style=''>all</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>not</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>highlighted</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>survey</span> <span style=''>methods</span> <span style=''>from</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disparate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>programs</span> <span style=''>over</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>We</span> <span style=''>discuss</span> <span style='background-color:rgba(0, 2 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Inferring</span> <span style=''>Graphs</span> <span style=''>from</span> <span style=''>Cascades</span> <span style=''>A</span> <span style=''>Sparse</span> <span style=''>Recovery</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Framework</span> <br/><br/><span style=''>In</span> <span style=''>the</span> <span style=''>Network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <span style=''>problem</span> <span style=''>one</span> <span style=''>seeks</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style=''>edges</span> <span style=''>of</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>graph</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3665158371040725);'>observations</span> <span style=''>of</span> <span style=''>cascades</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285714);'>propagating</span> <span style=''>over</span> <span style=''>this</span> <span style=''>graph</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>approach</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>from</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>recovery</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>general</span> <span style=''>model</span> <span style=''>of</span> <span style=''>cascades</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>the</span> <span style=''>voter</span> <span style=''>model</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>cascade</span> <span style=''>model</span> <span style=''>for</span> <span style=''>which</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>recovers</span> <span style=''>the</span> <span style=''>graphs</span> <span style=''>edges</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>and</span> <span style=''>O(slog</span> <span style=''>m)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>where</span> <span style=''>s</span> <span style=''>is</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>and</span> <span style=''>m</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>nodes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>also</span> <span style=''>recovers</span> <span style=''>the</span> <span style=''>edge</span> <span style=''>weights</span> <span style=''>(the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>diffusion</span> <span style=''>process)</span> <span style=''>and</span> <span style=''>is</span> <span style=''>robust</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classification</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Anti</span> <span style=''>Profile</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>anti</span> <span style=''>profile</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>(apSVM)</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>address</span> <span style=''>the</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problem</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>where</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinguish</span> <span style=''>data</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalous</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style=''>classes</span> <span style=''>based</span> <span style=''>on</span> <span style=''>their</span> <span style=''>pattern</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deviation</span> <span style=''>from</span> <span style=''>a</span> <span style=''>normal</span> <span style=''>stable</span> <span style=''>class</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>defined</span> <span style=''>here</span> <span style=''>that</span> <span style=''>the</span> <span style=''>apSVM</span> <span style=''>can</span> <span style=''>be</span> <span style=''>solved</span> <span style=''>as</span> <span style=''>the</span> <span style=''>dual</span> <span style=''>of</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>SVM</span> <span style=''>with</span> <span style=''>an</span> <span style=''>indirect</span> <span style=''>kernel</span> <span style=''>that</span> <span style=''>measures</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>anomalous</span> <span style=''>samples</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>to</span> <span style=''>the</span> <span style=''>stable</span> <span style=''>normal</span> <span style=''>class</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style=''>this</span> <span style=''>indirect</span> <span style=''>kernel</span> <span style=''>as</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reproducing</span> <span style=''>Kernel</span> <span style=''>Hilbert</span> <span style=''>Space</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representers</span> <span style=''>that</span> <span s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10588235294117647)
# 	experimental (0.13511586452762922)
# 	representation (0.13297682709447414)
# 	information (0.24527629233511586)
# 	segmentation (0.07950089126559715)
# 	architecture (0.09518716577540107)
# 	detection (0.12156862745098039)
# 	different (0.2641711229946524)
# 	recognition (0.12834224598930483)
# 	convolutional (0.14188948306595364)
#
# Some Statistics words are:
# 	distributions (0.12280701754385964)
# 	algorithm (0.39398496240601505)
# 	variables (0.13483709273182956)
# 	estimation (0.17393483709273183)
# 	statistical (0.15839598997493734)
# 	theoretical (0.1568922305764411)
# 	distribution (0.19147869674185464)
# 	inference (0.19899749373433584)
# 	regression (0.16942355889724312)
# 	dimensional (0.19598997493734335)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d2b8bb22-3a56-42b3-8137-b14913778e07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2b8bb22-3a56-42b3-8137-b14913778e07")) {                    Plotly.newPlot(                        "d2b8bb22-3a56-42b3-8137-b14913778e07",                        [{"x":["construction","architecture","uncorrelated","apparently","automatic","addressing","processes","fundamental","organizing","framework","difficult","autonomous","organization","clustering","competitive","expresses","experimental","consistently","information","sensitive","expressions","different","linguistic","knowledge","paraphrases","supervision","achieving","selection","answering","capturing","performance","paraphrase","progressively","empirically","parameters","excluding","available","demonstrate","computation","improvement","accelerate","experiments","effective","benchmark","evaluations","approaches","practical","acquisition","implemented","synthetic","objectives","overheads","evaluation","environmental","optimization","functions","determines","propagate","structure","controllable","recurrent","structural","feedforward","translation","gradients","including","contributing","analysing","significantly","consequence","simulator","considerable","realistic","algorithms","alternative","efficiency","components","reinforcement","inference","undesirable","baselines","attracted","heuristic","modulated","influence","perception","extracting","nonstationary","circumstances","frequency","dimension","predictability","subcomponent","switching","transition","similarity","embedding","component","successfully","coefficients","denoising","formulated","principles","variation","promising","smoothing","variational","inpainting","regularization","investigates","dimensional","functional","minimization","supervised","extensive","processing","demonstrated","classification","approximate","compressed","combination","exhibiting","introduced","regression","therefore","belonging","comparable","previously","introduce","correlated","measurement","formulation","literature","regularizer","conceptually","integrated","integrating","guidelines","incorporating","evolution","ontologies","represented","consistency","languages","techniques","management","specified","lifecycle","probabilistic","illustrate","empirical","scalability","overfitting","representation","parametric","advantages","attending","sequential","distances","construct","sequences","distributed","specifications","objective","constraint","programming","inequality","important","graphical","scientific","implementation","convergence","generated","constraints","quadratic","evaluated","interface","distribute","unsupervised","outperforms","complexity","handwritten","boltzmann","superpixel","recognition","constructed","categorize","computational","efficient","algorithm","restricted","effectively","superpixels","iterative","technique","categories","laplacian","dependency","providing","generalizes","structured","particular","equations","encompasses","competitiveness","challenging","regularized","reproducing","presented","classifier","descriptions","condition","auxiliary","generative","coherence","conditioned","comparison","synthesizing","adversarial","corresponding","inception","discriminability","diversity","intrinsics","comprising","photorealistic","registered","viewpoint","resolution","measurements","calibration","uncalibrated","resulting","dependent","photometric","intrinsic","stitching","geometric","renderings","multiview","unification","proportional","discounting","following","conjunctive","redistribution","responses","procedure","disjunctive","specificity","generalization","development","significant","hypotheses","understanding","hypothesis","conv ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	profitable
# 	collapsed
# 	parallelizes
# 	incoherence
# 	transferable
# 	parametrisation
# 	spectrometry
# 	lookahead
# 	representable
# 	electrocardiograms
# 	smoothers
# 	backfitting
# 	tibshirani
# 	dimensionalities
# 	backpropagating
# 	inferential
# 	heteroscedastic
# 	heteroscedasticity
# 	explanatory
# 	complicate
# Some words which never appear in Statistics papers:
# 	paraphrases
# 	paraphrase
# 	ontologies
# 	lifecycle
# 	attending
# 	superpixel
# 	discriminability
# 	intrinsics
# 	photorealistic
# 	uncalibrated
# 	photometric
# 	renderings
# 	redistribution
# 	paragraph
# 	textureless
# 	contrasts
# 	phonological
# 	initializes
# 	coordinating
# 	plasticity

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.067766972420775e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
